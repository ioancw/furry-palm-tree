# %%
# %%time
import random
from math import exp, sqrt
# Out:
# CPU times: user 15 µs, sys: 1 µs, total: 16 µs
# Wall time: 18.1 µs

# %%
# %%time
s_0 = 100
r = 0.05
T = 1.0
sigma = 0.2

values = []
for _ in range(1000000):
    s_T = s_0 * exp((r - 0.5 * sigma **2) * T +
        sigma * random.gauss(0,1) * sqrt(T))
    values.append(s_T)
# Out:
# CPU times: user 1.93 s, sys: 16.2 ms, total: 1.95 s
# Wall time: 1.95 s

# %%
# %%time
import numpy as np
s_0 = 100
r = 0.05
T = 1.0
sigma = 0.2
value = s_0 * np.exp((r - 0.5 * sigma ** 2) * T +
                sigma * np.random.standard_normal(100000) * np.sqrt(T))
# Out:
# CPU times: user 6.35 ms, sys: 955 µs, total: 7.31 ms
# Wall time: 5.7 ms

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %%
import quandl as q  
d = q.get('BCHAIN/MKPRU')  
d['SMA'] = d['Value'].rolling(100).mean()  
d[d.index > '2013-1-1'].plot(title='BTC/USD exchange rate',
                             figsize=(10, 6))
