# %%
# Ioan

# %%
Markdown cells
here testing.
# Out:
#   File "<ipython-input-2-52f8c3e0003a>", line 1
#     Markdown cells
#                  ^
# SyntaxError: invalid syntax

# %%
from ggplot import *
# %matplotlin inline
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-1d8c461f6fa3> in <module>()
# ----> 1 from ggplot import *
#       2 get_ipython().magic('matplotlin inline')
#       3 import pandas as pd
#
# ImportError: No module named 'ggplot'

# %%
# Import required modules
from ggplot import *
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-bcfd96a87c59> in <module>()
#       1
#       2 # Import required modules
# ----> 3 from ggplot import *
#
# ImportError: No module named 'ggplot'

# %%
from ggplot import *

# %%
file = '/Users/ioanwilliams/Downloads/table.csv'

# %%
dis = pd.read_csv(file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-11876b639f13> in <module>()
# ----> 1 dis = pd.read_csv(file)
#
# NameError: name 'pd' is not defined

# %%
from ggplot import *
# %matplotlin inline
import pandas as pd
# Out:
# ERROR:root:Line magic function `%matplotlin` not found.

# %%
from ggplot import *
# %matplotlib inline
import pandas as pd

# %%
file
# Out:
# '/Users/ioanwilliams/Downloads/table.csv'

# %%
dis = pd.read_csv(file)

# %%
dis
# Out:
#              Date        Open        High         Low       Close    Volume  \
# 0      2017-01-06  108.019997  109.349998  107.750000  108.980003   9263300
# 1      2017-01-05  107.169998  107.620003  106.790001  107.379997   6292500
# 2      2017-01-04  106.639999  107.500000  106.250000  107.440002   8231900
# 3      2017-01-03  105.300003  106.900002  105.209999  106.080002   8872900
# 4      2016-12-30  104.570000  105.000000  103.959999  104.220001   6629500
# 5      2016-12-29  104.230003  104.769997  103.870003  104.559998   5892000
# 6      2016-12-28  104.989998  105.320000  104.059998  104.300003   5116200
# 7      2016-12-27  104.849998  105.559998  104.779999  105.169998   3634300
# 8      2016-12-23  105.239998  105.339996  104.750000  105.150002   3231000
# 9      2016-12-22  104.959999  105.489998  104.699997  105.419998   5230800
# 10     2016-12-21  104.610001  105.910004  104.510002  105.559998   5202400
# ...

# %%
ggplot(dis, aes(x='Date',y='Adj Close')) + geom_line()
# Out:
# <ggplot: (295871969)>

# %%
dis.head()
# Out:
#          Date        Open        High         Low       Close   Volume  \
# 0  2017-01-06  108.019997  109.349998  107.750000  108.980003  9263300
# 1  2017-01-05  107.169998  107.620003  106.790001  107.379997  6292500
# 2  2017-01-04  106.639999  107.500000  106.250000  107.440002  8231900
# 3  2017-01-03  105.300003  106.900002  105.209999  106.080002  8872900
# 4  2016-12-30  104.570000  105.000000  103.959999  104.220001  6629500
#
#     Adj Close
# 0  108.980003
# 1  107.379997
# 2  107.440002
# 3  106.080002
# 4  104.220001

# %%
dis.describe
# Out:
# <bound method NDFrame.describe of              Date        Open        High         Low       Close    Volume  \
# 0      2017-01-06  108.019997  109.349998  107.750000  108.980003   9263300
# 1      2017-01-05  107.169998  107.620003  106.790001  107.379997   6292500
# 2      2017-01-04  106.639999  107.500000  106.250000  107.440002   8231900
# 3      2017-01-03  105.300003  106.900002  105.209999  106.080002   8872900
# 4      2016-12-30  104.570000  105.000000  103.959999  104.220001   6629500
# 5      2016-12-29  104.230003  104.769997  103.870003  104.559998   5892000
# 6      2016-12-28  104.989998  105.320000  104.059998  104.300003   5116200
# 7      2016-12-27  104.849998  105.559998  104.779999  105.169998   3634300
# 8      2016-12-23  105.239998  105.339996  104.750000  105.150002   3231000
# 9      2016-12-22  104.959999  105.489998  104.699997  105.419998   5230800
# 10     2016-12-21  104.610001  105.910004  104.510002  105.559998   5202400
# ...

# %%
dis.ftypes
# Out:
# Date          object:dense
# Open         float64:dense
# High         float64:dense
# Low          float64:dense
# Close        float64:dense
# Volume         int64:dense
# Adj Close    float64:dense
# dtype: object

# %%
dis.plot()

# %%
dis['Date'] = pd.to_datetime(dis['Date'])

# %%
dis2 = dis

# %%
dis2.index = dis2['Date']

# %%
del dis2['Date']

# %%
dis2
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2017-01-06  108.019997  109.349998  107.750000  108.980003   9263300
# 2017-01-05  107.169998  107.620003  106.790001  107.379997   6292500
# 2017-01-04  106.639999  107.500000  106.250000  107.440002   8231900
# 2017-01-03  105.300003  106.900002  105.209999  106.080002   8872900
# 2016-12-30  104.570000  105.000000  103.959999  104.220001   6629500
# 2016-12-29  104.230003  104.769997  103.870003  104.559998   5892000
# 2016-12-28  104.989998  105.320000  104.059998  104.300003   5116200
# 2016-12-27  104.849998  105.559998  104.779999  105.169998   3634300
# 2016-12-23  105.239998  105.339996  104.750000  105.150002   3231000
# 2016-12-22  104.959999  105.489998  104.699997  105.419998   5230800
# 2016-12-21  104.610001  105.910004  104.510002  105.559998   5202400
# 2016-12-20  105.639999  106.199997  105.059998  105.459999   8947300
# ...

# %%
dis3 = dis2['1/1/2007':]

# %%
dis3 = dis2.truncate(after = '1/1/2007')

# %%
dis3.plot()

# %%
import seaborn as sns

# %%
sns.set(style='darkgrid')

# %%
dis4 = pd.read_csv(file, index_col='Date')

# %%
dis4
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2017-01-06  108.019997  109.349998  107.750000  108.980003   9263300
# 2017-01-05  107.169998  107.620003  106.790001  107.379997   6292500
# 2017-01-04  106.639999  107.500000  106.250000  107.440002   8231900
# 2017-01-03  105.300003  106.900002  105.209999  106.080002   8872900
# 2016-12-30  104.570000  105.000000  103.959999  104.220001   6629500
# 2016-12-29  104.230003  104.769997  103.870003  104.559998   5892000
# 2016-12-28  104.989998  105.320000  104.059998  104.300003   5116200
# 2016-12-27  104.849998  105.559998  104.779999  105.169998   3634300
# 2016-12-23  105.239998  105.339996  104.750000  105.150002   3231000
# 2016-12-22  104.959999  105.489998  104.699997  105.419998   5230800
# 2016-12-21  104.610001  105.910004  104.510002  105.559998   5202400
# 2016-12-20  105.639999  106.199997  105.059998  105.459999   8947300
# ...

# %%
dis4.describe
# Out:
# <bound method NDFrame.describe of                   Open        High         Low       Close    Volume  \
# Date
# 2017-01-06  108.019997  109.349998  107.750000  108.980003   9263300
# 2017-01-05  107.169998  107.620003  106.790001  107.379997   6292500
# 2017-01-04  106.639999  107.500000  106.250000  107.440002   8231900
# 2017-01-03  105.300003  106.900002  105.209999  106.080002   8872900
# 2016-12-30  104.570000  105.000000  103.959999  104.220001   6629500
# 2016-12-29  104.230003  104.769997  103.870003  104.559998   5892000
# 2016-12-28  104.989998  105.320000  104.059998  104.300003   5116200
# 2016-12-27  104.849998  105.559998  104.779999  105.169998   3634300
# 2016-12-23  105.239998  105.339996  104.750000  105.150002   3231000
# 2016-12-22  104.959999  105.489998  104.699997  105.419998   5230800
# 2016-12-21  104.610001  105.910004  104.510002  105.559998   5202400
# 2016-12-20  105.639999  106.199997  105.059998  105.459999   8947300
# ...

# %%
pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
# Out:
# /Users/ioanwilliams/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2881: FutureWarning:
# mpl_style had been deprecated and will be removed in a future version.
# Use `matplotlib.pyplot.style.use` instead.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
dis.plot()

# %%
dis3.plot()

# %%
figsize(15,15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-cec4bf008aaa> in <module>()
# ----> 1 figsize(15,15)
#
# NameError: name 'figsize' is not defined

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('ggplot')

# %%
dis3.plot()

# %%
dis5
